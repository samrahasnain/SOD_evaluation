# %%
# !python main.py --dataset="LFSD"
# Out:
# eval[MAE]:LFSD dataset .
# eval[FMeasure]:LFSD dataset .
# eval[EMeasure]:LFSD dataset .
# eval[SMeasure]:LFSD dataset .
# [cost:42.8662s]LFSD dataset  get 0.0745 mae, 0.8655 max-fmeasure, 0.8952 max-Emeasure, 0.8592 S-measure..

# %%
# !python main.py --dataset="NJU2K_test"
# Out:
# eval[MAE]:NJU2K_test dataset .
# eval[FMeasure]:NJU2K_test dataset .
# eval[EMeasure]:NJU2K_test dataset .
# eval[SMeasure]:NJU2K_test dataset .
# [cost:1102.6048s]NJU2K_test dataset  get 0.0370 mae, 0.9207 max-fmeasure, 0.9528 max-Emeasure, 0.9185 S-measure..

# %%
# !python main.py --dataset="NLPR" --cuda=False
# Out:
# ./pred_maps\NLPR\10_01-00-59_JLDCF.png     ./gt\NLPR\10_01-00-59_GT.png
# ./pred_maps\NLPR\10_01-02-01_JLDCF.png     ./gt\NLPR\10_01-02-01_GT.png
# ./pred_maps\NLPR\10_01-05-11_JLDCF.png     ./gt\NLPR\10_01-05-11_GT.png
# ./pred_maps\NLPR\10_01-06-39_JLDCF.png     ./gt\NLPR\10_01-06-39_GT.png
# ./pred_maps\NLPR\10_01-10-53_JLDCF.png     ./gt\NLPR\10_01-10-53_GT.png
# ./pred_maps\NLPR\10_01-11-07_JLDCF.png     ./gt\NLPR\10_01-11-07_GT.png
# ./pred_maps\NLPR\10_01-13-37_JLDCF.png     ./gt\NLPR\10_01-13-37_GT.png
# ./pred_maps\NLPR\10_01-16-00_JLDCF.png     ./gt\NLPR\10_01-16-00_GT.png
# ./pred_maps\NLPR\10_01-16-04_JLDCF.png     ./gt\NLPR\10_01-16-04_GT.png
# ./pred_maps\NLPR\10_01-16-21_JLDCF.png     ./gt\NLPR\10_01-16-21_GT.png
# ./pred_maps\NLPR\10_01-17-25_JLDCF.png     ./gt\NLPR\10_01-17-25_GT.png
# ./pred_maps\NLPR\10_01-17-42_JLDCF.png     ./gt\NLPR\10_01-17-42_GT.png
# ./pred_maps\NLPR\10_01-18-10_JLDCF.png     ./gt\NLPR\10_01-18-10_GT.png
# ...

# %%
# !python main.py --dataset="RGBD135" --cuda=False
# Out:
# ./pred_maps\RGBD135\RGBD_data_100_JLDCF.png     ./gt\RGBD135\RGBD_data_100_GT.png
# ./pred_maps\RGBD135\RGBD_data_101_JLDCF.png     ./gt\RGBD135\RGBD_data_101_GT.png
# ./pred_maps\RGBD135\RGBD_data_102_JLDCF.png     ./gt\RGBD135\RGBD_data_102_GT.png
# ./pred_maps\RGBD135\RGBD_data_103_JLDCF.png     ./gt\RGBD135\RGBD_data_103_GT.png
# ./pred_maps\RGBD135\RGBD_data_104_JLDCF.png     ./gt\RGBD135\RGBD_data_104_GT.png
# ./pred_maps\RGBD135\RGBD_data_105_JLDCF.png     ./gt\RGBD135\RGBD_data_105_GT.png
# ./pred_maps\RGBD135\RGBD_data_106_JLDCF.png     ./gt\RGBD135\RGBD_data_106_GT.png
# ./pred_maps\RGBD135\RGBD_data_107_JLDCF.png     ./gt\RGBD135\RGBD_data_107_GT.png
# ./pred_maps\RGBD135\RGBD_data_108_JLDCF.png     ./gt\RGBD135\RGBD_data_108_GT.png
# ./pred_maps\RGBD135\RGBD_data_109_JLDCF.png     ./gt\RGBD135\RGBD_data_109_GT.png
# ./pred_maps\RGBD135\RGBD_data_10_JLDCF.png     ./gt\RGBD135\RGBD_data_10_GT.png
# ...

# %%
# !python main.py --dataset="SIP" --cuda=False
# Out:
# ./pred_maps\SIP\100_JLDCF.png     ./gt\SIP\100_GT.png
# ./pred_maps\SIP\101_JLDCF.png     ./gt\SIP\101_GT.png
# ./pred_maps\SIP\102_JLDCF.png     ./gt\SIP\102_GT.png
# ./pred_maps\SIP\103_JLDCF.png     ./gt\SIP\103_GT.png
# ./pred_maps\SIP\104_JLDCF.png     ./gt\SIP\104_GT.png
# ./pred_maps\SIP\105_JLDCF.png     ./gt\SIP\105_GT.png
# ./pred_maps\SIP\106_JLDCF.png     ./gt\SIP\106_GT.png
# ./pred_maps\SIP\107_JLDCF.png     ./gt\SIP\107_GT.png
# ./pred_maps\SIP\108_JLDCF.png     ./gt\SIP\108_GT.png
# ./pred_maps\SIP\109_JLDCF.png     ./gt\SIP\109_GT.png
# ./pred_maps\SIP\10_JLDCF.png     ./gt\SIP\10_GT.png
# ./pred_maps\SIP\110_JLDCF.png     ./gt\SIP\110_GT.png
# ./pred_maps\SIP\111_JLDCF.png     ./gt\SIP\111_GT.png
# ./pred_maps\SIP\112_JLDCF.png     ./gt\SIP\112_GT.png
# ./pred_maps\SIP\113_JLDCF.png     ./gt\SIP\113_GT.png
# ./pred_maps\SIP\114_JLDCF.png     ./gt\SIP\114_GT.png
# ./pred_maps\SIP\115_JLDCF.png     ./gt\SIP\115_GT.png
# ...

# %%
# !python main.py --dataset="STERE" --cuda=False
# Out:
# ./pred_maps\STERE\image_left1000_JLDCF.png     ./gt\STERE\image_left1000_GT.png
# ./pred_maps\STERE\image_left100_JLDCF.png     ./gt\STERE\image_left100_GT.png
# ./pred_maps\STERE\image_left101_JLDCF.png     ./gt\STERE\image_left101_GT.png
# ./pred_maps\STERE\image_left102_JLDCF.png     ./gt\STERE\image_left102_GT.png
# ./pred_maps\STERE\image_left103_JLDCF.png     ./gt\STERE\image_left103_GT.png
# ./pred_maps\STERE\image_left104_JLDCF.png     ./gt\STERE\image_left104_GT.png
# ./pred_maps\STERE\image_left105_JLDCF.png     ./gt\STERE\image_left105_GT.png
# ./pred_maps\STERE\image_left106_JLDCF.png     ./gt\STERE\image_left106_GT.png
# ./pred_maps\STERE\image_left107_JLDCF.png     ./gt\STERE\image_left107_GT.png
# ./pred_maps\STERE\image_left108_JLDCF.png     ./gt\STERE\image_left108_GT.png
# ./pred_maps\STERE\image_left109_JLDCF.png     ./gt\STERE\image_left109_GT.png
# ./pred_maps\STERE\image_left10_JLDCF.png     ./gt\STERE\image_left10_GT.png
# ...
